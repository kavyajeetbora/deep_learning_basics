# %%
# write some shell commands

# %%
# !ls
# Out:
# sample_data

# %%
# check the computer specification provided by google colab
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single pti ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13335276 kB
# MemFree:        11535980 kB
# MemAvailable:   12662556 kB
# Buffers:           62960 kB
# Cached:          1231208 kB
# SwapCached:            0 kB
# Active:           516744 kB
# Inactive:        1067116 kB
# Active(anon):     266872 kB
# Inactive(anon):      340 kB
# Active(file):     249872 kB
# Inactive(file):  1066776 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               284 kB
# Writeback:             0 kB
# AnonPages:        289728 kB
# Mapped:           155480 kB
# Shmem:               864 kB
# Slab:             130076 kB
# SReclaimable:     102216 kB
# SUnreclaim:        27860 kB
# KernelStack:        3712 kB
# PageTables:         4684 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6667636 kB
# Committed_AS:    1814032 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %% [markdown]
# this is a text where i can write in **bold**
# i can also write in $\LaTeX$

# %% [markdown]
# # Section 1

# %% [markdown]
# this is a independent cell

# %% [markdown]
# # Section 2

# %% [markdown]
# this is another section, these are like contents of a table
